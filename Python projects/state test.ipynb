# %% [markdown]
# modeling
#     assuptions
#     mathematical equations and physic laws
#     ideal solution

# %% [markdown]
# steps
#     independent variable
#     dependent variable
#     equation to link them together
#     use numpy and math
